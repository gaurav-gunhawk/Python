# %%
# !pip install pydeck

# %%
import pydeck as pdk
import pandas as pd

# %%
# UK_ACCIDENTS_DATA = ('https://raw.githubusercontent.com/uber-common/'
#                     'deck.gl-data/master/examples/3d-heatmap/heatmap-data.csv')

# %%
UK_ACCIDENTS_DATA  = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Files_To_Read/indian_states_lat_long.csv")
UK_ACCIDENTS_DATA = UK_ACCIDENTS_DATA[['lat' , 'lng']]
UK_ACCIDENTS_DATA
# Out:
#            lat        lng
# 0    18.987807  72.836447
# 1    28.651952  77.231495
# 2    22.562627  88.363044
# 3    13.084622  80.248357
# 4    12.977063  77.587106
# ..         ...        ...
# 207  11.248016  75.780402
# 208  19.331589  79.466051
# 209  26.913312  75.787872
# 210  23.216667  72.683333
# 211  30.691512  76.853736
#
# [212 rows x 2 columns]

# %%
layer = pdk.Layer(
    'ScatterplotLayer',
    UK_ACCIDENTS_DATA,
    get_position=['lng', 'lat'],
    auto_highlight=True,
    get_radius=10000,
    get_fill_color='[180, 0, 200, 140]',
    pickable=True)

view_state = pdk.ViewState(
    longitude=78.962883,
    latitude=20.593683,
    zoom=6,
    min_zoom=5,
    max_zoom=15,
    pitch=40.5,
    bearing=-27.36)

# Combined all of it and render a viewport
r = pdk.Deck(layers=[layer], initial_view_state=view_state , mapbox_key="pk.eyJ1IjoiZ2F1cmF2Z3VwdGEwNyIsImEiOiJja2QxdXo5dDkwdWQ4MzZxbXN5a3k1MnFvIn0.qf2qnag9B9uU6OoONVokPQ")
r.to_html('demomo.html', notebook_display=False)
# r.show()
